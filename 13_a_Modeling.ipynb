# %%
# Importing Required Python Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
# Loading Reduced feature Training set
X_train_red = pd.read_csv('X_train_final.csv')
y_train = pd.read_csv('y_train.final.csv')

# %%
# Loading Reduced feature Test set
X_test_red = pd.read_csv('X_test_final.csv')
y_test = pd.read_csv('y_test.final.csv')

# %% [markdown]
# ## Model_16: Weighted Aggregating Classifier

# %% [markdown]
# ####  Loading  the best Voting Classifier model & Neural Network (with Equal Nodes in all the Layers)

# %%
# Importing Joblib module
import joblib

# %%
import tensorflow
from tensorflow import keras

# %%
# Importing best Voting Classifier
voting_clf = joblib.load('Voting_Red.joblib')

# %%
# Importing best Neural Net Classifier
neural = keras.models.load_model('Best_model_Selu_eq_Learn.h5')

# %% [markdown]
# ### Performing 10 fold class validations to get best weights for Voting and Neural Calssifiers

# %%
from sklearn.model_selection import StratifiedKFold

# %%
# Initializing the 10 Fold object
cv_strat = StratifiedKFold(10,random_state=42)

# %%
# Defining the prediction matrices for the voting & Neural classifiers
y_preds_vote = np.empty((10, int(len(X_train_red)/10)), dtype=np.float32)
y_preds_neural = np.empty((10, int(len(X_train_red)/10)), dtype=np.float32)
y_true = np.empty((10, int(len(X_train_red)/10)), dtype=np.float32)

# %% [markdown]
# ### Getting predictions of the Voting classifier for each fold of Training set.

# %%
# Computing  10 fold  CV predictions on the training set for the Voting Classifier
i = 0
for train_index, test_index in cv_strat.split(X_train_red, y_train):
    # Creating  Folds
    X_tr, X_tst = X_train_red.loc[train_index], X_train_red.loc[test_index]
    y_tr, y_tst = y_train.loc[train_index], y_train.loc[test_index]
    # Fitting the best Voting Classifier
    voting_clf.fit(X_tr, y_tr)
    y_pred = voting_clf.predict_proba(X_tst)[:,1]
    # Storing the fold predictions in a numpy array
    y_preds_vote[i,:] = y_pred
    # Storing the true fold values in a numpy array
    y_true[i,:] = y_tst.values.flatten()
    i = i+1

# %%
#y_preds_vote.shape
y_true.shape
# Out:
# (10, 3295)

# %%
# Storing the copies of the Voting classifier Predictions & True Class labels for each instance of each test fold.
y_preds_vote_copy = y_preds_vote.copy()
y_true_copy = y_true.copy()

# %%
# Turning predictions & corresponding class labels into column vectors.
y_preds_vote = y_preds_vote.reshape(-1,1)
y_true = y_true.reshape(-1,1)

# %%
y_true_copy.shape
# Out:
# (10, 3295)

# %%
# Saving the Voting Predictions & True class labels for each test fold
pd.DataFrame(y_preds_vote_copy).to_csv('Voting_Preds_Folds.csv',index=False)
pd.DataFrame(y_true_copy).to_csv('True_Labels_Folds.csv',index=False)

# %% [markdown]
# ### Getting predictions for the Neural classifier for each fold

# %%
# # Importing train test split from Sklearn to produce validation set
from sklearn.model_selection import train_test_split

# %%
# Defining the exponential decay learning rate.
def exponential_decay_fn(epoch):
            return 0.01 * 0.1**(epoch /4 )

# %%
# Computing  10 fold  CV predictions on the training set for the Neural Network
i = 0
for train_index, test_index in cv_strat.split(X_train_red, y_train):
    # Creating  Folds
    X_tr, X_tst = X_train_red.loc[train_index], X_train_red.loc[test_index]
    y_tr, y_tst = y_train.loc[train_index], y_train.loc[test_index]
    
    # Splitting the Training set further into training & validation set.
    X_tr_r, X_val, y_tr_r, y_val = train_test_split(X_tr, y_tr, test_size=0.1, random_state=42, stratify=y_tr)
    
    # Loading fresh keras model on every iteration
    neural = keras.models.load_model('Best_model_Selu_eq_Learn.h5')
    
    # comiling & Training the Neural Net
    neural.compile(loss="binary_crossentropy", optimizer=keras.optimizers.Nadam(beta_1=0.9, beta_2=0.999), metrics=["accuracy"])
    
    # defining Checkpoints
    checkpoint_cb = keras.callbacks.ModelCheckpoint('best_model.h5',save_best_only=True) # 1st Callback
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=10)# 2nd Callback
    lr_scheduler_cb = keras.callbacks.LearningRateScheduler(exponential_decay_fn)# 3rd Callback
    
    # Fitting The model
    neural.fit(X_tr_r, y_tr_r, epochs=50, validation_data=(X_val,y_val),batch_size=32,
    class_weight={0: 1.0, 1: 10.0},callbacks=[checkpoint_cb,early_stopping_cb,lr_scheduler_cb])
    
    # Loading the best Neural model after training & before making predictions
    neural_best = keras.models.load_model('best_model.h5')    
    
    # Saving the predictions for every fold in a numpy array
    y_pred = neural_best.predict_proba(X_tst)
    y_preds_neural[i,:] = y_pred.flatten()
    i = i+1
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 4s 140us/sample - loss: 1.1999 - accuracy: 0.6931 - val_loss: 1.1904 - val_accuracy: 0.7333
# Epoch 2/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.1355 - accuracy: 0.7297 - val_loss: 1.0706 - val_accuracy: 0.8247
# Epoch 3/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.1027 - accuracy: 0.7559 - val_loss: 1.0679 - val_accuracy: 0.7923
# Epoch 4/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0893 - accuracy: 0.7723 - val_loss: 1.0714 - val_accuracy: 0.7997
# Epoch 5/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0799 - accuracy: 0.7783 - val_loss: 1.1207 - val_accuracy: 0.5539
# Epoch 6/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0704 - accuracy: 0.7800 - val_loss: 1.0556 - val_accuracy: 0.7893
# Epoch 7/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0627 - accuracy: 0.7832 - val_loss: 1.0544 - val_accuracy: 0.7913
# Epoch 8/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0588 - accuracy: 0.7861 - val_loss: 1.0553 - val_accuracy: 0.7980
# Epoch 9/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0558 - accuracy: 0.7904 - val_loss: 1.0539 - val_accuracy: 0.8119
# Epoch 10/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0539 - accuracy: 0.7960 - val_loss: 1.0528 - val_accuracy: 0.7913
# Epoch 11/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0527 - accuracy: 0.7888 - val_loss: 1.0534 - val_accuracy: 0.7933
# Epoch 12/50
# 26689/26689 [==============================] - 2s 84us/sample - loss: 1.0520 - accuracy: 0.7870 - val_loss: 1.0536 - val_accuracy: 0.7964
# Epoch 13/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0515 - accuracy: 0.7904 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 14/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0512 - accuracy: 0.7902 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 15/50
# 26689/26689 [==============================] - 2s 87us/sample - loss: 1.0511 - accuracy: 0.7902 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 16/50
# 26689/26689 [==============================] - 2s 83us/sample - loss: 1.0510 - accuracy: 0.7903 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 17/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0510 - accuracy: 0.7902 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 18/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0510 - accuracy: 0.7900 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 19/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0509 - accuracy: 0.7902 - val_loss: 1.0535 - val_accuracy: 0.7960
# Epoch 20/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0509 - accuracy: 0.7900 - val_loss: 1.0535 - val_accuracy: 0.7960
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 105us/sample - loss: 1.1850 - accuracy: 0.7023 - val_loss: 1.3000 - val_accuracy: 0.4922
# Epoch 2/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.1340 - accuracy: 0.7314 - val_loss: 1.1393 - val_accuracy: 0.8439
# Epoch 3/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0999 - accuracy: 0.7566 - val_loss: 1.1135 - val_accuracy: 0.6757
# Epoch 4/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0819 - accuracy: 0.7723 - val_loss: 1.1030 - val_accuracy: 0.7997
# Epoch 5/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0683 - accuracy: 0.7855 - val_loss: 1.0992 - val_accuracy: 0.8186
# Epoch 6/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0578 - accuracy: 0.7833 - val_loss: 1.0780 - val_accuracy: 0.7856
# Epoch 7/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0513 - accuracy: 0.7862 - val_loss: 1.0777 - val_accuracy: 0.7920
# Epoch 8/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0468 - accuracy: 0.7926 - val_loss: 1.0860 - val_accuracy: 0.7967
# Epoch 9/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0434 - accuracy: 0.7852 - val_loss: 1.0850 - val_accuracy: 0.8014
# Epoch 10/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0413 - accuracy: 0.7908 - val_loss: 1.0828 - val_accuracy: 0.7876
# Epoch 11/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0394 - accuracy: 0.7805 - val_loss: 1.0866 - val_accuracy: 0.8021
# Epoch 12/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0392 - accuracy: 0.7919 - val_loss: 1.0836 - val_accuracy: 0.7940
# Epoch 13/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0387 - accuracy: 0.7876 - val_loss: 1.0839 - val_accuracy: 0.7953
# Epoch 14/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0384 - accuracy: 0.7883 - val_loss: 1.0839 - val_accuracy: 0.7947
# Epoch 15/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0382 - accuracy: 0.7874 - val_loss: 1.0840 - val_accuracy: 0.7957
# Epoch 16/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0382 - accuracy: 0.7880 - val_loss: 1.0841 - val_accuracy: 0.7957
# Epoch 17/50
# 26689/26689 [==============================] - 3s 97us/sample - loss: 1.0381 - accuracy: 0.7880 - val_loss: 1.0841 - val_accuracy: 0.7957
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 120us/sample - loss: 1.1916 - accuracy: 0.6968 - val_loss: 2.0462 - val_accuracy: 0.8881
# Epoch 2/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.1334 - accuracy: 0.7321 - val_loss: 1.0954 - val_accuracy: 0.8092
# Epoch 3/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.1016 - accuracy: 0.7502 - val_loss: 1.1120 - val_accuracy: 0.7266
# Epoch 4/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0843 - accuracy: 0.7672 - val_loss: 1.0837 - val_accuracy: 0.8051
# Epoch 5/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0725 - accuracy: 0.7796 - val_loss: 1.0784 - val_accuracy: 0.8119
# Epoch 6/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0628 - accuracy: 0.7835 - val_loss: 1.0849 - val_accuracy: 0.7714
# Epoch 7/50
# 26689/26689 [==============================] - 2s 84us/sample - loss: 1.0562 - accuracy: 0.7782 - val_loss: 1.0900 - val_accuracy: 0.7967
# Epoch 8/50
# 26689/26689 [==============================] - 2s 87us/sample - loss: 1.0509 - accuracy: 0.7788 - val_loss: 1.0833 - val_accuracy: 0.7960
# Epoch 9/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0479 - accuracy: 0.7830 - val_loss: 1.0814 - val_accuracy: 0.7916
# Epoch 10/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0463 - accuracy: 0.7794 - val_loss: 1.0857 - val_accuracy: 0.8048
# Epoch 11/50
# 26689/26689 [==============================] - 2s 86us/sample - loss: 1.0453 - accuracy: 0.7867 - val_loss: 1.0830 - val_accuracy: 0.7957
# Epoch 12/50
# 26689/26689 [==============================] - 2s 90us/sample - loss: 1.0443 - accuracy: 0.7849 - val_loss: 1.0821 - val_accuracy: 0.7903
# Epoch 13/50
# 26689/26689 [==============================] - 2s 87us/sample - loss: 1.0439 - accuracy: 0.7835 - val_loss: 1.0822 - val_accuracy: 0.7903
# Epoch 14/50
# 26689/26689 [==============================] - 2s 88us/sample - loss: 1.0437 - accuracy: 0.7831 - val_loss: 1.0821 - val_accuracy: 0.7886
# Epoch 15/50
# 26689/26689 [==============================] - 2s 85us/sample - loss: 1.0435 - accuracy: 0.7817 - val_loss: 1.0821 - val_accuracy: 0.7903
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 102us/sample - loss: 1.1832 - accuracy: 0.7122 - val_loss: 1.4875 - val_accuracy: 0.7947
# Epoch 2/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.1170 - accuracy: 0.7439 - val_loss: 1.2894 - val_accuracy: 0.8773
# Epoch 3/50
# 26689/26689 [==============================] - 2s 85us/sample - loss: 1.0880 - accuracy: 0.7720 - val_loss: 1.0821 - val_accuracy: 0.8058
# Epoch 4/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0707 - accuracy: 0.7850 - val_loss: 1.0901 - val_accuracy: 0.8216
# Epoch 5/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0591 - accuracy: 0.7872 - val_loss: 1.0862 - val_accuracy: 0.8105
# Epoch 6/50
# 26689/26689 [==============================] - 2s 71us/sample - loss: 1.0526 - accuracy: 0.7931 - val_loss: 1.0799 - val_accuracy: 0.7920
# Epoch 7/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0454 - accuracy: 0.7977 - val_loss: 1.0837 - val_accuracy: 0.7835
# Epoch 8/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0414 - accuracy: 0.7958 - val_loss: 1.0784 - val_accuracy: 0.7927
# Epoch 9/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0378 - accuracy: 0.7974 - val_loss: 1.0811 - val_accuracy: 0.7916
# Epoch 10/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0361 - accuracy: 0.7917 - val_loss: 1.0815 - val_accuracy: 0.8024
# Epoch 11/50
# 26689/26689 [==============================] - 2s 88us/sample - loss: 1.0350 - accuracy: 0.7958 - val_loss: 1.0827 - val_accuracy: 0.8071
# Epoch 12/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0345 - accuracy: 0.8005 - val_loss: 1.0818 - val_accuracy: 0.8024
# Epoch 13/50
# 26689/26689 [==============================] - 2s 82us/sample - loss: 1.0340 - accuracy: 0.7965 - val_loss: 1.0818 - val_accuracy: 0.8028
# Epoch 14/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0338 - accuracy: 0.7970 - val_loss: 1.0818 - val_accuracy: 0.8014
# Epoch 15/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0337 - accuracy: 0.7973 - val_loss: 1.0818 - val_accuracy: 0.8018
# Epoch 16/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0336 - accuracy: 0.7968 - val_loss: 1.0819 - val_accuracy: 0.8021
# Epoch 17/50
# 26689/26689 [==============================] - 2s 72us/sample - loss: 1.0336 - accuracy: 0.7968 - val_loss: 1.0819 - val_accuracy: 0.8021
# Epoch 18/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0335 - accuracy: 0.7968 - val_loss: 1.0819 - val_accuracy: 0.8021
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 126us/sample - loss: 1.1855 - accuracy: 0.7106 - val_loss: 1.4613 - val_accuracy: 0.8270
# Epoch 2/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.1270 - accuracy: 0.7409 - val_loss: 1.2007 - val_accuracy: 0.6295
# Epoch 3/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0920 - accuracy: 0.7657 - val_loss: 1.1270 - val_accuracy: 0.7974
# Epoch 4/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0744 - accuracy: 0.7773 - val_loss: 1.0880 - val_accuracy: 0.7856
# Epoch 5/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0632 - accuracy: 0.7826 - val_loss: 1.1033 - val_accuracy: 0.8223
# Epoch 6/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0562 - accuracy: 0.7861 - val_loss: 1.0945 - val_accuracy: 0.7980
# Epoch 7/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0501 - accuracy: 0.7914 - val_loss: 1.0906 - val_accuracy: 0.7775
# Epoch 8/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0463 - accuracy: 0.7866 - val_loss: 1.0887 - val_accuracy: 0.7923
# Epoch 9/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0423 - accuracy: 0.7860 - val_loss: 1.0916 - val_accuracy: 0.8092
# Epoch 10/50
# 26689/26689 [==============================] - 2s 92us/sample - loss: 1.0401 - accuracy: 0.7903 - val_loss: 1.0911 - val_accuracy: 0.8011
# Epoch 11/50
# 26689/26689 [==============================] - 2s 88us/sample - loss: 1.0392 - accuracy: 0.7912 - val_loss: 1.0906 - val_accuracy: 0.7994
# Epoch 12/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0384 - accuracy: 0.7898 - val_loss: 1.0904 - val_accuracy: 0.7977
# Epoch 13/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0380 - accuracy: 0.7888 - val_loss: 1.0906 - val_accuracy: 0.7994
# Epoch 14/50
# 26689/26689 [==============================] - 2s 86us/sample - loss: 1.0378 - accuracy: 0.7901 - val_loss: 1.0905 - val_accuracy: 0.7994
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 121us/sample - loss: 1.1938 - accuracy: 0.7019 - val_loss: 1.6673 - val_accuracy: 0.8810
# Epoch 2/50
# 26689/26689 [==============================] - 2s 84us/sample - loss: 1.1293 - accuracy: 0.7304 - val_loss: 1.4895 - val_accuracy: 0.8904
# Epoch 3/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0962 - accuracy: 0.7541 - val_loss: 1.6950 - val_accuracy: 0.1851
# Epoch 4/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0909 - accuracy: 0.7567 - val_loss: 1.1241 - val_accuracy: 0.8466
# Epoch 5/50
# 26689/26689 [==============================] - 2s 89us/sample - loss: 1.0679 - accuracy: 0.7739 - val_loss: 1.1102 - val_accuracy: 0.8355
# Epoch 6/50
# 26689/26689 [==============================] - 2s 88us/sample - loss: 1.0597 - accuracy: 0.7823 - val_loss: 1.0880 - val_accuracy: 0.8085
# Epoch 7/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0515 - accuracy: 0.7828 - val_loss: 1.0914 - val_accuracy: 0.8139
# Epoch 8/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0481 - accuracy: 0.7864 - val_loss: 1.0812 - val_accuracy: 0.7805
# Epoch 9/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0443 - accuracy: 0.7838 - val_loss: 1.0868 - val_accuracy: 0.8088
# Epoch 10/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0424 - accuracy: 0.7871 - val_loss: 1.0849 - val_accuracy: 0.8058
# Epoch 11/50
# 26689/26689 [==============================] - 2s 85us/sample - loss: 1.0413 - accuracy: 0.7884 - val_loss: 1.0831 - val_accuracy: 0.7953
# Epoch 12/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0405 - accuracy: 0.7871 - val_loss: 1.0831 - val_accuracy: 0.7957
# Epoch 13/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0400 - accuracy: 0.7889 - val_loss: 1.0826 - val_accuracy: 0.7916
# Epoch 14/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0397 - accuracy: 0.7868 - val_loss: 1.0826 - val_accuracy: 0.7913
# Epoch 15/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0396 - accuracy: 0.7869 - val_loss: 1.0825 - val_accuracy: 0.7920
# Epoch 16/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0395 - accuracy: 0.7865 - val_loss: 1.0826 - val_accuracy: 0.7913
# Epoch 17/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0395 - accuracy: 0.7867 - val_loss: 1.0826 - val_accuracy: 0.7913
# Epoch 18/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0395 - accuracy: 0.7867 - val_loss: 1.0826 - val_accuracy: 0.7913
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 111us/sample - loss: 1.1792 - accuracy: 0.7074 - val_loss: 1.2914 - val_accuracy: 0.8493
# Epoch 2/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.1244 - accuracy: 0.7376 - val_loss: 1.1638 - val_accuracy: 0.8436
# Epoch 3/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0875 - accuracy: 0.7655 - val_loss: 1.1066 - val_accuracy: 0.8173
# Epoch 4/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0730 - accuracy: 0.7848 - val_loss: 1.0720 - val_accuracy: 0.7980
# Epoch 5/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0612 - accuracy: 0.7849 - val_loss: 1.0788 - val_accuracy: 0.8068
# Epoch 6/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0554 - accuracy: 0.7937 - val_loss: 1.0833 - val_accuracy: 0.7980
# Epoch 7/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0508 - accuracy: 0.7949 - val_loss: 1.0781 - val_accuracy: 0.8169
# Epoch 8/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0461 - accuracy: 0.7962 - val_loss: 1.0802 - val_accuracy: 0.8216
# Epoch 9/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0436 - accuracy: 0.7955 - val_loss: 1.0764 - val_accuracy: 0.8156
# Epoch 10/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.0423 - accuracy: 0.8001 - val_loss: 1.0736 - val_accuracy: 0.8038
# Epoch 11/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0412 - accuracy: 0.7987 - val_loss: 1.0731 - val_accuracy: 0.8021
# Epoch 12/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0406 - accuracy: 0.7938 - val_loss: 1.0733 - val_accuracy: 0.8045
# Epoch 13/50
# 26689/26689 [==============================] - ETA: 0s - loss: 1.0405 - accuracy: 0.79 - 2s 79us/sample - loss: 1.0402 - accuracy: 0.7956 - val_loss: 1.0736 - val_accuracy: 0.8055
# Epoch 14/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0400 - accuracy: 0.7959 - val_loss: 1.0737 - val_accuracy: 0.8058
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 109us/sample - loss: 1.1941 - accuracy: 0.7089 - val_loss: 1.7307 - val_accuracy: 0.5722
# Epoch 2/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.1497 - accuracy: 0.7271 - val_loss: 4.9493 - val_accuracy: 0.1150
# Epoch 3/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.1335 - accuracy: 0.7452 - val_loss: 1.1762 - val_accuracy: 0.7943
# Epoch 4/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0792 - accuracy: 0.7776 - val_loss: 1.0739 - val_accuracy: 0.8041
# Epoch 5/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0649 - accuracy: 0.7848 - val_loss: 1.0744 - val_accuracy: 0.8082
# Epoch 6/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0557 - accuracy: 0.7898 - val_loss: 1.1602 - val_accuracy: 0.4063
# Epoch 7/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0551 - accuracy: 0.7847 - val_loss: 1.0670 - val_accuracy: 0.8125
# Epoch 8/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0433 - accuracy: 0.7983 - val_loss: 1.0691 - val_accuracy: 0.8206
# Epoch 9/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0400 - accuracy: 0.7977 - val_loss: 1.0709 - val_accuracy: 0.8304
# Epoch 10/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0372 - accuracy: 0.8026 - val_loss: 1.0653 - val_accuracy: 0.8051
# Epoch 11/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0360 - accuracy: 0.7976 - val_loss: 1.0672 - val_accuracy: 0.8159
# Epoch 12/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0354 - accuracy: 0.8008 - val_loss: 1.0669 - val_accuracy: 0.8152
# Epoch 13/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0346 - accuracy: 0.8068 - val_loss: 1.0649 - val_accuracy: 0.8041
# Epoch 14/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0346 - accuracy: 0.7946 - val_loss: 1.0657 - val_accuracy: 0.8088
# Epoch 15/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0344 - accuracy: 0.8014 - val_loss: 1.0657 - val_accuracy: 0.8088
# Epoch 16/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0344 - accuracy: 0.8010 - val_loss: 1.0657 - val_accuracy: 0.8088
# Epoch 17/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0343 - accuracy: 0.8010 - val_loss: 1.0657 - val_accuracy: 0.8092
# Epoch 18/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0343 - accuracy: 0.8013 - val_loss: 1.0657 - val_accuracy: 0.8092
# Epoch 19/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0343 - accuracy: 0.8010 - val_loss: 1.0657 - val_accuracy: 0.8092
# Epoch 20/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0343 - accuracy: 0.8010 - val_loss: 1.0657 - val_accuracy: 0.8092
# Epoch 21/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0342 - accuracy: 0.8012 - val_loss: 1.0658 - val_accuracy: 0.8092
# Epoch 22/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0342 - accuracy: 0.8011 - val_loss: 1.0657 - val_accuracy: 0.8092
# Epoch 23/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0342 - accuracy: 0.8011 - val_loss: 1.0658 - val_accuracy: 0.8092
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 104us/sample - loss: 1.2019 - accuracy: 0.6913 - val_loss: 1.2984 - val_accuracy: 0.7626
# Epoch 2/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.1313 - accuracy: 0.7322 - val_loss: 1.4106 - val_accuracy: 0.8651
# Epoch 3/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.1047 - accuracy: 0.7630 - val_loss: 1.0927 - val_accuracy: 0.8189
# Epoch 4/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0826 - accuracy: 0.7809 - val_loss: 1.1554 - val_accuracy: 0.8098
# Epoch 5/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0725 - accuracy: 0.7797 - val_loss: 1.0792 - val_accuracy: 0.7900
# Epoch 6/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0614 - accuracy: 0.7851 - val_loss: 1.0797 - val_accuracy: 0.7775
# Epoch 7/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0546 - accuracy: 0.7859 - val_loss: 1.0689 - val_accuracy: 0.7906
# Epoch 8/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0489 - accuracy: 0.7883 - val_loss: 1.0699 - val_accuracy: 0.7980
# Epoch 9/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0455 - accuracy: 0.7862 - val_loss: 1.0709 - val_accuracy: 0.7964
# Epoch 10/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0436 - accuracy: 0.7906 - val_loss: 1.0692 - val_accuracy: 0.7984
# Epoch 11/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0421 - accuracy: 0.7932 - val_loss: 1.0687 - val_accuracy: 0.8004
# Epoch 12/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0415 - accuracy: 0.7911 - val_loss: 1.0687 - val_accuracy: 0.7997
# Epoch 13/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0410 - accuracy: 0.7907 - val_loss: 1.0688 - val_accuracy: 0.8007
# Epoch 14/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0407 - accuracy: 0.7916 - val_loss: 1.0688 - val_accuracy: 0.8004
# Epoch 15/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0406 - accuracy: 0.7925 - val_loss: 1.0688 - val_accuracy: 0.7997
# Epoch 16/50
# 26689/26689 [==============================] - 2s 73us/sample - loss: 1.0405 - accuracy: 0.7920 - val_loss: 1.0688 - val_accuracy: 0.8001
# Epoch 17/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0405 - accuracy: 0.7919 - val_loss: 1.0687 - val_accuracy: 0.8001
# Epoch 18/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0404 - accuracy: 0.7920 - val_loss: 1.0687 - val_accuracy: 0.8001
# Epoch 19/50
# 26689/26689 [==============================] - 2s 74us/sample - loss: 1.0404 - accuracy: 0.7918 - val_loss: 1.0687 - val_accuracy: 0.8001
# Epoch 20/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0404 - accuracy: 0.7918 - val_loss: 1.0687 - val_accuracy: 0.8001
# Epoch 21/50
# 26689/26689 [==============================] - 2s 75us/sample - loss: 1.0404 - accuracy: 0.7919 - val_loss: 1.0687 - val_accuracy: 0.8001
# Epoch 22/50
# 26689/26689 [==============================] - 2s 76us/sample - loss: 1.0404 - accuracy: 0.7919 - val_loss: 1.0687 - val_accuracy: 0.8001
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 26689 samples, validate on 2966 samples
# Epoch 1/50
# 26689/26689 [==============================] - 3s 106us/sample - loss: 1.1728 - accuracy: 0.7092 - val_loss: 1.1852 - val_accuracy: 0.7906
# Epoch 2/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.1270 - accuracy: 0.7451 - val_loss: 1.9349 - val_accuracy: 0.1534
# Epoch 3/50
# 26689/26689 [==============================] - 2s 79us/sample - loss: 1.1104 - accuracy: 0.7565 - val_loss: 1.1541 - val_accuracy: 0.7347
# Epoch 4/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0766 - accuracy: 0.7883 - val_loss: 1.1610 - val_accuracy: 0.8685
# Epoch 5/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0618 - accuracy: 0.7877 - val_loss: 1.0898 - val_accuracy: 0.7401
# Epoch 6/50
# 26689/26689 [==============================] - 2s 77us/sample - loss: 1.0520 - accuracy: 0.7914 - val_loss: 1.1103 - val_accuracy: 0.8510
# Epoch 7/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0438 - accuracy: 0.7963 - val_loss: 1.0925 - val_accuracy: 0.8358
# Epoch 8/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0382 - accuracy: 0.7959 - val_loss: 1.0859 - val_accuracy: 0.8196
# Epoch 9/50
# 26689/26689 [==============================] - 2s 85us/sample - loss: 1.0352 - accuracy: 0.8007 - val_loss: 1.0803 - val_accuracy: 0.7738
# Epoch 10/50
# 26689/26689 [==============================] - 2s 83us/sample - loss: 1.0331 - accuracy: 0.7863 - val_loss: 1.0831 - val_accuracy: 0.8102
# Epoch 11/50
# 26689/26689 [==============================] - 2s 86us/sample - loss: 1.0317 - accuracy: 0.7950 - val_loss: 1.0829 - val_accuracy: 0.8095
# Epoch 12/50
# 26689/26689 [==============================] - 2s 78us/sample - loss: 1.0309 - accuracy: 0.7982 - val_loss: 1.0817 - val_accuracy: 0.8045
# Epoch 13/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0306 - accuracy: 0.7926 - val_loss: 1.0829 - val_accuracy: 0.8085
# Epoch 14/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0303 - accuracy: 0.7940 - val_loss: 1.0831 - val_accuracy: 0.8082
# Epoch 15/50
# 26689/26689 [==============================] - 2s 83us/sample - loss: 1.0301 - accuracy: 0.7955 - val_loss: 1.0833 - val_accuracy: 0.8092
# Epoch 16/50
# 26689/26689 [==============================] - 2s 83us/sample - loss: 1.0301 - accuracy: 0.7974 - val_loss: 1.0833 - val_accuracy: 0.8085
# Epoch 17/50
# 26689/26689 [==============================] - 2s 81us/sample - loss: 1.0300 - accuracy: 0.7968 - val_loss: 1.0833 - val_accuracy: 0.8085
# Epoch 18/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0300 - accuracy: 0.7970 - val_loss: 1.0833 - val_accuracy: 0.8085
# Epoch 19/50
# 26689/26689 [==============================] - 2s 80us/sample - loss: 1.0300 - accuracy: 0.7970 - val_loss: 1.0833 - val_accuracy: 0.8085

# %%
# storing a copy of the Neural predictions for each fold in a numpy array & finally into a csv file
y_preds_neural_copy = y_preds_neural.copy()
pd.DataFrame(y_preds_neural_copy).to_csv('Neural_Preds_Folds.csv',index=False)

# %%
y_preds_neural_copy.shape
# Out:
# (10, 3295)

# %%
# Turning  neural predictions  into column vector.
y_preds_neural = y_preds_neural.reshape(-1,1)

# %%
# Confirming that voting classifier predictions , Neural predictions & True class labels have same shape
assert y_preds_neural.shape == y_preds_vote.shape == y_true.shape

# %%
# importing optuna
import optuna

# %%
# Importing the Sklearn's roc_auc_score module
from sklearn.metrics import roc_auc_score

# %%
# Declaring objective function for Weighted Aggregation Classifier
def objective_wrappper_auc(y_pred_cls_1, y_pred_cls_2, y_true):
    '''
    Optimizes weights for predictions from 2 classifiers to achieve maximum roc_auc score
      
    '''
    
    def objective(trial):
        w1 = trial.suggest_uniform('w1',-1,1)
        w2 = trial.suggest_uniform('w2',-1,1)
        
        y_final_pred = y_pred_cls_1 * w1 + y_pred_cls_2 * w2
        
        roc_auc_1 = roc_auc_score(y_true,y_final_pred)
        
                   
        return roc_auc_1
    
    return objective

# %%
# Defining the evaluation function for study's best parameters
def roc_auc_weights(y_pred_cls_1, y_pred_cls_2, y_true, obj_func, n_trials=200):
    ''' Computes the best hyper parameters of the classsifier on the Training set and returns 
    Optuna's study's best score & clasifier parameters'''
    study = optuna.create_study(direction='maximize')
    study.optimize(obj_func(y_pred_cls_1, y_pred_cls_2, y_true),n_trials)
    best_score = study.best_value
    best_params = study.best_params
    return (best_score,best_params)

# %%
best_study_score,best_study_params = roc_auc_weights(y_preds_vote, y_preds_neural, y_true, objective_wrappper_auc,1000)
# Out:
# [I 2020-10-22 20:50:39,728] A new study created in memory with name: no-name-71c0ebaf-46fa-4c9e-8128-78407d00dc52
# [I 2020-10-22 20:50:39,742] Trial 0 finished with value: 0.7712874965945355 and parameters: {'w1': -0.38504861498674847, 'w2': 0.7245313701325928}. Best is trial 0 with value: 0.7712874965945355.
# [I 2020-10-22 20:50:39,753] Trial 1 finished with value: 0.1999509340407264 and parameters: {'w1': -0.7600424066570979, 'w2': -0.22465585974897562}. Best is trial 0 with value: 0.7712874965945355.
# [I 2020-10-22 20:50:39,764] Trial 2 finished with value: 0.764979670962859 and parameters: {'w1': -0.40084637154122915, 'w2': 0.6740586199414385}. Best is trial 0 with value: 0.7712874965945355.
# [I 2020-10-22 20:50:39,776] Trial 3 finished with value: 0.8002498326383827 and parameters: {'w1': 0.3536713490623571, 'w2': -0.021919771475948258}. Best is trial 3 with value: 0.8002498326383827.
# [I 2020-10-22 20:50:40,011] Trial 19 finished with value: 0.7856861009954571 and parameters: {'w1': 0.9720237223939329, 'w2': -0.5343925285988094}. Best is trial 17 with value: 0.8003968545303586.
# [I 2020-10-22 20:50:40,027] Trial 20 finished with value: 0.7993875388532519 and parameters: {'w1': 0.8400588144314147, 'w2': 0.4443592453263253}. Best is trial 17 with value: 0.8003968545303586.
# [I 2020-10-22 20:50:40,041] Trial 21 finished with value: 0.8004135455438836 and parameters: {'w1': 0.41493000110455075, 'w2': 0.008534229760384211}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,057] Trial 22 finished with value: 0.8000451362229951 and parameters: {'w1': 0.7333210875506727, 'w2': -0.07942430645882313}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,072] Trial 23 finished with value: 0.799725030870313 and parameters: {'w1': 0.9957558143449448, 'w2': 0.4118786879882947}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,086] Trial 24 finished with value: 0.7982226691955556 and parameters: {'w1': 0.0662985760639252, 'w2': 0.06351294183764294}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,102] Trial 25 finished with value: 0.7952028027708391 and parameters: {'w1': 0.5043931140938247, 'w2': -0.19515878044117815}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,117] Trial 26 finished with value: 0.7901128821122607 and parameters: {'w1': 0.7917157753451264, 'w2': -0.38928996755020384}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,134] Trial 27 finished with value: 0.7972703830675598 and parameters: {'w1': 0.37818637605995337, 'w2': -0.1200678797808108}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,149] Trial 28 finished with value: 0.7994316504884998 and parameters: {'w1': 0.6386639962138818, 'w2': 0.3286038191780244}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,164] Trial 29 finished with value: 0.20804814873210584 and parameters: {'w1': -0.011047033981504084, 'w2': -0.8370248747533978}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,179] Trial 30 finished with value: 0.7902697168275343 and parameters: {'w1': 0.8829914794701442, 'w2': -0.4320439068177016}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,194] Trial 31 finished with value: 0.8004124444806122 and parameters: {'w1': 0.45105250191200624, 'w2': 0.03972811698234813}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,210] Trial 32 finished with value: 0.7999706509051163 and parameters: {'w1': 0.4408946930262774, 'w2': 0.14286864427759904}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,226] Trial 33 finished with value: 0.7972298280048873 and parameters: {'w1': 0.7055725693549783, 'w2': -0.225239243928258}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,242] Trial 34 finished with value: 0.20581415585173757 and parameters: {'w1': -0.08160577011433526, 'w2': 0.03370900983762867}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,256] Trial 35 finished with value: 0.22294682013664313 and parameters: {'w1': -0.9249298291560305, 'w2': 0.5812110563725967}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,272] Trial 36 finished with value: 0.8002558585411405 and parameters: {'w1': 0.27722539722849204, 'w2': 0.0548928874627304}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,288] Trial 37 finished with value: 0.1998442000077839 and parameters: {'w1': -0.6225229692253369, 'w2': -0.15375181160641063}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,303] Trial 38 finished with value: 0.7969006193006385 and parameters: {'w1': 0.911450821775841, 'w2': -0.30262311192826286}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,319] Trial 39 finished with value: 0.8003232675695422 and parameters: {'w1': 0.6134788446235964, 'w2': -0.02281434956403712}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,335] Trial 40 finished with value: 0.7964980263417824 and parameters: {'w1': 0.13014865218094174, 'w2': 0.24400167968946015}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,351] Trial 41 finished with value: 0.8003261699538979 and parameters: {'w1': 0.615519469406572, 'w2': -0.022120411632526878}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,365] Trial 42 finished with value: 0.8001721086281197 and parameters: {'w1': 0.41299952659882944, 'w2': 0.09896369150957596}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,380] Trial 43 finished with value: 0.8002435856015789 and parameters: {'w1': 0.8247166934765944, 'w2': -0.05266388463368245}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,395] Trial 44 finished with value: 0.7992501316853245 and parameters: {'w1': 0.5374639746620924, 'w2': 0.30957127790383776}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,411] Trial 45 finished with value: 0.7990124356205079 and parameters: {'w1': 0.684873420303385, 'w2': -0.15385252287861842}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,426] Trial 46 finished with value: 0.7838068485877495 and parameters: {'w1': 0.5092256478410888, 'w2': -0.29013902485160337}. Best is trial 21 with value: 0.8004135455438836.
# [I 2020-10-22 20:50:40,441] Trial 47 finished with value: 0.8004242475103256 and parameters: {'w1': 0.9845607223824389, 'w2': 0.04528447955527431}. Best is trial 47 with value: 0.8004242475103256.
# [I 2020-10-22 20:50:40,456] Trial 48 finished with value: 0.8003755104879456 and parameters: {'w1': 0.9833251774257676, 'w2': 0.1314520895953768}. Best is trial 47 with value: 0.8004242475103256.
# [I 2020-10-22 20:50:40,471] Trial 49 finished with value: 0.799227308808978 and parameters: {'w1': 0.9732449656902292, 'w2': 0.5683797961957824}. Best is trial 47 with value: 0.8004242475103256.
. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:56,953] Trial 983 finished with value: 0.8003224843864621 and parameters: {'w1': 0.8037097365397203, 'w2': -0.03004309502688953}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:56,972] Trial 984 finished with value: 0.8003810250182214 and parameters: {'w1': 0.9206244657450513, 'w2': 0.11834070354528753}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:56,991] Trial 985 finished with value: 0.8004147940298525 and parameters: {'w1': 0.8334491206943333, 'w2': 0.014673106281661203}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,010] Trial 986 finished with value: 0.8001959127867962 and parameters: {'w1': 0.8879856586996385, 'w2': -0.0683635532886079}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,030] Trial 987 finished with value: 0.8004230635217868 and parameters: {'w1': 0.9491171743991366, 'w2': 0.04635333161634446}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,049] Trial 988 finished with value: 0.7980195621811247 and parameters: {'w1': 0.786036718190875, 'w2': 0.8206089800258871}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,067] Trial 989 finished with value: 0.8003803477952051 and parameters: {'w1': 0.8780105642662102, 'w2': -0.008711062987934282}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,086] Trial 990 finished with value: 0.8004059164192914 and parameters: {'w1': 0.9504103259760562, 'w2': 0.0977223651252146}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,105] Trial 991 finished with value: 0.8004262653584966 and parameters: {'w1': 0.747345505420047, 'w2': 0.027602933656587426}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,125] Trial 992 finished with value: 0.8004212622007024 and parameters: {'w1': 0.9173530427158979, 'w2': 0.060040365907898574}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,145] Trial 993 finished with value: 0.8003330988206774 and parameters: {'w1': 0.8338784464233053, 'w2': -0.028526809845224974}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,169] Trial 994 finished with value: 0.8002728904696533 and parameters: {'w1': 0.7591252366399182, 'w2': 0.1445454595719948}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,192] Trial 995 finished with value: 0.8004139739910981 and parameters: {'w1': 0.8630230011184696, 'w2': 0.01615838501224956}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,214] Trial 996 finished with value: 0.7999572492605277 and parameters: {'w1': 0.9620286757757802, 'w2': -0.11851951787336246}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,234] Trial 997 finished with value: 0.8004140753442025 and parameters: {'w1': 0.909256404733586, 'w2': 0.07718322624840235}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,257] Trial 998 finished with value: 0.8002185928474046 and parameters: {'w1': 0.8005422333242358, 'w2': -0.056661124682250735}. Best is trial 902 with value: 0.8004266845917924.
# [I 2020-10-22 20:50:57,280] Trial 999 finished with value: 0.8004198985407512 and parameters: {'w1': 0.8486112144448726, 'w2': 0.023807398428264213}. Best is trial 902 with value: 0.8004266845917924.

# %%
print('The best roc_auc_score for the study is: ',best_study_score)
# Out:
# The best roc_auc_score for the study is:  0.8004266845917924

# %%
print(('The best study parameters for the classifier are: ',best_study_params))
# Out:
# ('The best study parameters for the classifier are: ', {'w1': 0.9397785734580625, 'w2': 0.03493904313818527})

# %% [markdown]
# ### Training the Tuned Weighted Aggregating Classifier on the whole Training set & making the predictions on the Test set.

# %%
# Training the voting classifier on whole Traing set
voting_clf.fit(X_train_red, y_train)
# Out:
# VotingClassifier(estimators=[('logistic_Reg',
#                               LogisticRegression(C=0.12725888493400458,
#                                                  class_weight={0: 1.0, 1: 9.0},
#                                                  l1_ratio=0.9851193622801032,
#                                                  n_jobs=5, penalty='elasticnet',
#                                                  random_state=42,
#                                                  solver='saga')),
#                              ('Random_Forest',
#                               RandomForestClassifier(class_weight='balanced',
#                                                      max_depth=11,
#                                                      min_samples_leaf=0.000264150675671259,
#                                                      n_estimators=1560,
#                                                      n_jobs=5,
#                                                      rando...
#                                              max_depth=85, min_child_samples=16,
#                                              n_estimators=1083, n_jobs=5,
#                                              num_leaves=26, objective='binary',
#                                              random_state=42,
#                                              reg_alpha=6.964534534541776,
#                                              reg_lambda=5.143496762382144)),
#                              ('Linear_Dis',
#                               LinearDiscriminantAnalysis(shrinkage=0.0023665526949698365,
#                                                          solver='eigen'))],
#                  n_jobs=5, voting='soft',
#                  weights=[0.01892659811471946, 0.12205104743904709,
#                           0.4097477051900742, 0.007396756446858069])

# %%
# Making Predictions on the Test Set using voting classifier
y_preds_vote_final = voting_clf.predict_proba(X_test_red)[:,1]

# %%
# Reloading best Neural Net Classifier 
neural = keras.models.load_model('Best_model_Selu_eq_Learn.h5')

# %%
# Making Predictions on the Test Set using Neural classifier
y_preds_neural_final = neural.predict_proba(X_test_red)

# %%
# Converting all test set  voting classifier  predictions into a column vector 
y_preds_vote_final = y_preds_vote_final.reshape(-1,1)

# %%
# combining the predictions from the Neural  & Voting classifier with the study's best votes.
y_combined_final = y_preds_vote_final * best_study_params['w1'] + y_preds_neural_final * best_study_params['w2']

# %%
# Computing the the final roc_auc score of the combined model 
print('The final test set roc_auc score of the combined voting & neural classifier using the best weights is: ',
     roc_auc_score(y_test,y_combined_final))
# Out:
# The final test set roc_auc score of the combined voting & neural classifier using the best weights is:  0.8173387453417614

# %% [markdown]
# ### Calculating R_R ratio of the tuned Weighted Aggregating classifier using study's best weights.

# %%
# Asserting that all the Predictions & True Call label arrays have same shape
assert y_preds_vote_copy.shape == y_true_copy.shape == y_preds_neural_copy.shape

# %%
roc_auc_agg = []
for i in range(10):
    y_pred_combined = y_preds_vote_copy[i,:] * best_study_params['w1'] + y_preds_neural_copy[i,:] * best_study_params['w2']
    roc_auc_agg.append(roc_auc_score(y_true_copy[i,:],y_pred_combined))

# %%
print('The reward associated with the Aggregating classifier using roc_auc metric is: ',np.mean(roc_auc_agg))
# Out:
# The reward associated with the Aggregating classifier using roc_auc metric is:  0.8014073062606618

# %%
print('The risk associated with the Aggregating Classifier using roc_auc metric is: ',np.std(roc_auc_agg))
# Out:
# The risk associated with the Aggregating Classifier using roc_auc metric is:  0.016844751862311692

# %%
R_R_Ratio_Aggregator = np.mean(roc_auc_agg)/np.std(roc_auc_agg)

# %%
print('The reward risk ratio for the Aggregating Classifier using roc_auc metric is: ',R_R_Ratio_Aggregator)
# Out:
# The reward risk ratio for the Aggregating Classifier using roc_auc metric is:  47.57608261678961

# %% [markdown]
# ## Observations:
# ### 1) The test set roc_auc score for the tuned Weighted Aggregating classifier is nearly equal to that of best tuned Voting Classifier, owing to more weight being assigned to the voting classifier.
# ### 2) Similarly the R_R ratio of the Weighted Aggregating classifier is approx. equal (although more) to that of the best tuned Voting Classifier. So with added complexity the former doesn't offer any advantage over the latter.

# %% [markdown]
# ### Best R_R Ratio for the tuned Weighted  Classifier using reduced feature set is:  47.57608261678961
